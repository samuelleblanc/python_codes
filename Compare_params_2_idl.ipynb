# %% [markdown]
# # Comparing parameters between python and IDL

# %% [markdown]
# Program that is used to test the results of params in the python vs. idl (original)
# Sets up the different basis for comparison in ipython
#
# Results:
#   - python implementation required a special derivative routine to use the 3 point lagrangian derivative method found in idl
#   - python also required a new method of calculating the linear fit. Previous was slightly off, and was returning absissa instead of slope
#   - Particularities between smoothing functions nearly not important except for parameter 2, which uses the derivative at a specific
#     wavelength, Wavelength adjusted to match better with 4STAR resolution than SSFR's

# %% [markdown]
# Load the required modules

# %%
# %config InlineBackend.rc = {}
import matplotlib
matplotlib.rc_file('C:\\Users\\sleblan2\\Research\\python_codes\\file.rc')
import matplotlib.pyplot as plt
from matplotlib import colors
# %matplotlib inline

# %%
import numpy as np, h5py
import plotly.plotly as py
import scipy.io as sio
import math
import os
import warnings
warnings.simplefilter('ignore', np.RankWarning)
import Sp_parameters as Sp
py.sign_in("samuelleblanc", "4y3khh7ld4")
#import mpld3
#mpld3.enable_notbeook()

# %%
reload(Sp)
# Out:
# <module 'Sp_parameters' from 'Sp_parameters.pyc'>

# %%
from Sp_parameters import nanmasked, closestindex, norm2max, find_closest, smooth, deriv
from scipy.interpolate import UnivariateSpline, splev, splrep

# %%
# set the basic directory path
fp='C:\\Users\\sleblan2\\Research\\TCAP\\'

# %%
# load the idl save file containing the modeled radiances and build the Sp modules
s=sio.idl.readsav(fp+'model/sp_v1_20130219_4STAR.out')
print s.keys()
print 'sp', s.sp.shape
print 'sp (wp, wvl, z, re, ta)'
lut = Sp.Sp(s)
lut.params()
# Out:
# ['tau', 'ab', 'pw', 'sp_irrdn', 'sp', 'zenlambda', 'sza', 'zout', 'sp_irrup', 'z', 'ref']
# sp (2, 1556, 2, 35, 24)
# sp (wp, wvl, z, re, ta)
# 1556 1556
# in sp
# (2, 1556, 2, 35, 24)
# (2, 1556, 2, 35, 24)
# Sp_parameters.py:442: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# Sp_parameters.py:66: RuntimeWarning:
#
# divide by zero encountered in float_scalars
# Sp_parameters.py:67: RuntimeWarning:
#
# divide by zero encountered in float_scalars
#
# Sp_parameters.py:67: RuntimeWarning:
#
# invalid value encountered in float_scalars
#
# Sp_parameters.py:70: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# Sp_parameters.py:71: RuntimeWarning:
#
# divide by zero encountered in float_scalars
#
# Sp_parameters.py:71: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# Sp_parameters.py:70: RuntimeWarning:
#
# divide by zero encountered in float_scalars
#
# Sp_parameters.py:70: RuntimeWarning:
#
# invalid value encountered in add
#
# Sp_parameters.py:97: RuntimeWarning:
#
# invalid value encountered in true_divide
# Sp_parameters.py:111: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Python27\lib\site-packages\numpy\lib\function_base.py:1248: RuntimeWarning:
#
# invalid value encountered in not_equal
#
# C:\Python27\lib\site-packages\numpy\lib\nanfunctions.py:607: RuntimeWarning:
#
# Mean of empty slice
#
# Sp_parameters.py:124: RuntimeWarning:
#
# divide by zero encountered in true_divide
# Sp_parameters.py:124: RuntimeWarning:
#
# invalid value encountered in true_divide
# array([[[[  1.76604450e-01,  -4.88962272e+00,   7.63206672e+00, ...,
#             2.05477762e+00,  -5.65592782e-05,   3.52036953e-02],
#          [  2.01116562e-01,  -4.95181203e+00,   8.11117905e+00, ...,
#             1.70327783e+00,  -6.35059478e-05,   5.63954487e-02],
#          [  2.06746161e-01,  -4.97066491e+00,   8.41963156e+00, ...,
#             1.59868991e+00,  -7.83015785e-05,   8.71705636e-02],
#          ...,
#          [  7.75061071e-01,  -4.23110313e+00,   1.05432083e+00, ...,
#             2.03249431e+00,   3.20757914e-04,   3.07462942e-02],
#          [  9.01518226e-01,  -4.07565946e+00,   6.98531872e-01, ...,
#             2.03983283e+00,   3.57200013e-04,   2.75956783e-02],
#          [  1.03742993e+00,  -3.91163769e+00,   4.56271883e-01, ...,
#             2.04717660e+00,   3.92991118e-04,   2.50308421e-02]],
#
#         [[  1.69181228e-01,  -4.90532821e+00,   8.57178349e+00, ...,
#             2.27164340e+00,  -4.11597066e-05,   3.38719152e-02],
#          [  1.95956945e-01,  -4.95879512e+00,   8.85252781e+00, ...,
#             1.85142541e+00,  -4.63138495e-05,   5.33813573e-02],
#          [  1.99752569e-01,  -4.95878053e+00,   8.84704636e+00, ...,
#             1.71086121e+00,  -5.80310334e-05,   8.23043883e-02],
#          ...,
#          [  7.86344051e-01,  -3.90985470e+00,   3.95446594e-01, ...,
#             1.96729302e+00,   4.89529571e-04,   3.49611640e-02],
#          [  9.29082274e-01,  -3.72159966e+00,   2.30279926e-01, ...,
#             1.97589886e+00,   5.46644966e-04,   3.14213522e-02],
#          [  1.08307028e+00,  -3.52956784e+00,   1.32212362e-01, ...,
#             1.98476231e+00,   6.03891502e-04,   2.85319444e-02]],
#
#         [[  1.50056243e-01,  -4.85362169e+00,   8.50416841e+00, ...,
#             2.39011884e+00,  -3.20020408e-05,   3.31630521e-02],
#          [  1.81490302e-01,  -4.91370667e+00,   8.73078011e+00, ...,
#             1.92851198e+00,  -3.75488344e-05,   5.17390706e-02],
#          [  1.88490510e-01,  -4.91806501e+00,   8.63682519e+00, ...,
#             1.76163995e+00,  -4.98810805e-05,   7.95438662e-02],
#          ...,
#          [  8.45823348e-01,  -3.61398027e+00,   2.39439423e-01, ...,
#             1.89137244e+00,   5.86536480e-04,   3.74893025e-02],
#          [  1.00607705e+00,  -3.38641295e+00,   1.30463033e-01, ...,
#             1.90056276e+00,   6.55798649e-04,   3.37206312e-02],
#          [  1.17916024e+00,  -3.15872240e+00,   7.01062016e-02, ...,
#             1.91021442e+00,   7.25865364e-04,   3.06400564e-02]],
#
#         ...,
#         [[             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          ...,
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          ...,
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          ...,
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00]]],
#
#
#        [[[             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          ...,
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          ...,
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00]],
#
#         [[             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          ...,
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00],
#          [             nan,              nan,              nan, ...,
#                        nan,   3.00000000e-03,   0.00000000e+00]],
#
#         ...,
#         [[  1.69021428e-01,  -4.92304637e+00,   5.98012097e+00, ...,
#             2.04427743e+00,  -1.44607043e-06,   5.12011759e-02],
#          [  1.73114479e-01,  -4.98379901e+00,   5.66009957e+00, ...,
#             1.81794739e+00,   2.18505011e-05,   8.72984156e-02],
#          [  1.63426101e-01,  -5.04136863e+00,   5.04576494e+00, ...,
#             1.74031341e+00,   8.13904699e-05,   1.23298422e-01],
#          ...,
#          [ -9.48867726e+00,  -5.22284422e+00,   0.00000000e+00, ...,
#             2.68816161e+00,   3.00000000e-03,   9.35897045e-03],
#          [ -1.06931780e+01,  -4.07149765e+00,   0.00000000e+00, ...,
#             2.99375510e+00,   3.00000000e-03,   8.34264141e-03],
#          [ -1.18222584e+01,  -3.13557130e+00,   0.00000000e+00, ...,
#             3.36127353e+00,   3.00000000e-03,   7.52513623e-03]],
#
#         [[  1.61563277e-01,  -4.92296892e+00,   5.92264176e+00, ...,
#             2.04609251e+00,   1.26631321e-07,   5.11103086e-02],
#          [  1.65033877e-01,  -4.98173588e+00,   5.59501794e+00, ...,
#             1.81894124e+00,   2.47666812e-05,   8.71424079e-02],
#          [  1.54132843e-01,  -5.03564569e+00,   4.97312582e+00, ...,
#             1.74089134e+00,   8.64768517e-05,   1.23163484e-01],
#          ...,
#          [ -1.14300878e+01,  -4.13766507e+00,   0.00000000e+00, ...,
#             2.67910266e+00,   3.00000000e-03,   9.39727575e-03],
#          [ -1.27770960e+01,  -3.13894464e+00,   0.00000000e+00, ...,
#             2.98174739e+00,   3.00000000e-03,   8.37705098e-03],
#          [ -1.40192055e+01,  -2.35259940e+00,   0.00000000e+00, ...,
#             3.34528255e+00,   3.00000000e-03,   7.55625591e-03]],
#
#         [[  1.61254764e-01,  -4.93967906e+00,   5.91098556e+00, ...,
#             2.04829502e+00,   4.64557317e-08,   5.10955006e-02],
#          [  1.64907396e-01,  -5.00494781e+00,   5.58209023e+00, ...,
#             1.82086444e+00,   2.45709307e-05,   8.71176273e-02],
#          [  1.54246747e-01,  -5.07041853e+00,   4.95888922e+00, ...,
#             1.74261725e+00,   8.59883003e-05,   1.23146422e-01],
#          ...,
#          [ -1.12028452e+01,  -5.13865711e+00,   0.00000000e+00, ...,
#             2.68102956e+00,   3.00000000e-03,   9.40787885e-03],
#          [ -1.25483140e+01,  -3.95588808e+00,   0.00000000e+00, ...,
#             2.98333740e+00,   3.00000000e-03,   8.38653371e-03],
#          [ -1.37979417e+01,  -3.00945214e+00,   0.00000000e+00, ...,
#             3.34653068e+00,   3.00000000e-03,   7.56483292e-03]]]])

# %%
# load the matlab file containing the measured TCAP radiances
m = sio.loadmat(fp+'4STAR/20130219starzen_rad.mat')
sm = sio.idl.AttrDict(m)
print sm.keys()
print 'Measured radiance Shape: ', sm.rad.shape
meas = Sp.Sp(m)
meas.params()
# Out:
# ['utc', 'rad', 'good', 'nm', '__version__', '__header__', '__globals__']
# Measured radiance Shape:  (3296, 1512)
# 1512 1512
# in rad
# (3296, 1512) 2 1512
# 1 in ui
# (3296, 1512)
# Sp_parameters.py:440: RuntimeWarning:
#
# invalid value encountered in true_divide
# array([[             nan,              nan,              nan, ...,
#                      nan,   3.00000000e-03,   0.00000000e+00],
#        [             nan,              nan,              nan, ...,
#                      nan,   3.00000000e-03,   0.00000000e+00],
#        [  2.55042291e-01,  -7.20468256e+00,   2.22356471e+00, ...,
#           1.78085070e+00,   9.10243252e-05,   1.34613313e-01],
#        ...,
#        [ -5.46783137e-01,  -1.31600910e+01,  -1.04698859e+01, ...,
#           4.97197251e+00,  -1.77487999e-03,   1.03114416e-01],
#        [ -6.05123501e-01,  -1.38189552e+01,  -1.10389829e+01, ...,
#           5.86628462e+00,  -3.36745426e-03,   1.04398753e-01],
#        [ -5.73305039e-01,  -1.38093414e+01,  -1.13697843e+01, ...,
#           8.91106171e+00,  -3.01085619e-03,   9.92880748e-02]])

# %% [markdown]
# Now go through comparing the two methods

# %%
print lut.par.shape
print lut.par[0,5,6,:]
p_0_5_6 = [ 0.169785, -0.672731 ,     7.21242 ,    0.979948 ,    0.194668,     0.109177,     0.338863,      3.11233,   -0.0178171,   -0.0139593,     -1.29179  ,   0.330518
      ,1.17178    ,  1.69885, -0.000469405 ,    0.178697]
print p_0_5_6
print lut.par[1,10,10,:]
p_1_10_10 = [0.132723570, -1.930865765,  0.662532628,  1.008047819,  0.163861081,  0.025557771,
             0.315011382, -0.094412826, -0.016095554, -0.006612694,-1.353369117,  0.306448370, 
             1.179942489,  1.728420854,  0.008580528,  0.051876802,]
print p_1_10_10
# Out:
# (2, 35, 24, 16)
# [  1.69793785e-01  -4.76297225e+00   7.16131549e+00   9.79947865e-01
#    1.95800692e-01   1.09287262e-01   3.39464009e-01   3.11233220e+00
#   -7.75574172e-03  -1.25353550e-02  -1.29266942e+00   3.30518007e-01
#    1.17177689e+00   1.69885159e+00  -9.75837393e-05   1.78697497e-01]
# [0.169785, -0.672731, 7.21242, 0.979948, 0.194668, 0.109177, 0.338863, 3.11233, -0.0178171, -0.0139593, -1.29179, 0.330518, 1.17178, 1.69885, -0.000469405, 0.178697]
# [  1.32722676e-01  -7.05205725e+00   6.63129396e-01   1.00804782e+00
#    1.64940357e-01   2.54985653e-02   3.15573961e-01  -9.44126714e-02
#   -4.42579885e-03  -5.17863290e-03  -1.35613990e+00   3.06448370e-01
#    1.17994249e+00   1.72842085e+00   5.29192679e-04   5.18768020e-02]
# [0.13272357, -1.930865765, 0.662532628, 1.008047819, 0.163861081, 0.025557771, 0.315011382, -0.094412826, -0.016095554, -0.006612694, -1.353369117, 0.30644837, 1.179942489, 1.728420854, 0.008580528, 0.051876802]

# %% [markdown]
# Plot the differences in parameters

# %%
fig4, ax4 = plt.subplots(1,2, figsize=(15,5))
ax4 = ax4.ravel()
ax4[0].plot(np.arange(16),lut.par[0,5,6,:],label='python')
ax4[0].plot(np.arange(16),p_0_5_6,label='idl')
ax4[0].set_title('difference in parameters - liquid example')
ax4[0].set_xlabel('Parameters')
ax4[0].legend()

ax4[1].plot(np.arange(16),lut.par[1,10,10,:],label='python')
ax4[1].plot(np.arange(16),p_1_10_10,label='idl')
ax4[1].set_title('difference in parameters - ice example')
ax4[1].set_xlabel('Parameters')
ax4[1].legend()

# %% [markdown]
# Create the desired arrays which are used in creating the parameters

# %%
s_0_5_6 = lut.sp[0,:,0,5,6]
s,n = nanmasked(s_0_5_6)
snorm = norm2max(s_0_5_6)
[i1000,i1077,i1493,i1600,i1200,i1300,i530,i610,
 i1565,i1634,i1193,i1198,i1236,i1248,i1270,i1644,
 i1050,i1040,i1065,i600,i870,i515] = find_closest(lut.wvl,np.array([1000,1077,1493,1600,1200,1300,530,
                                                     610,1565,1634,1193,1198,1236,1248,
                                                     1270,1644,1050,1040,1065,600,870,515]))
norm2 = s_0_5_6/s_0_5_6[i1000]
dsp = smooth(np.gradient(norm2,lut.wvl/1000.),2)

# %%
norm2_uni = UnivariateSpline(lut.wvl/1000.0,norm2,k=5)
norm2_uni.set_smoothing_factor(1)
dnorm2 = norm2_uni.derivative()

# %%
norm2_bspline = splrep(lut.wvl/1000.0,norm2,k=5)
norm2_b = splev(lut.wvl/1000.0,norm2_bspline,der=0)
dbnorm2 = splev(lut.wvl/1000.0,norm2_bspline,der=1)

# %%
dsp2 = smooth(deriv(norm2,lut.wvl/1000.),2)

# %%
plt.figure()
plt.plot(lut.wvl,norm2)
plt.plot(lut.wvl,norm2_uni(lut.wvl/1000.0))
plt.plot(lut.wvl,norm2_b)
plt.figure()
plt.plot(lut.wvl,dnorm2(lut.wvl/1000.0))
plt.plot(lut.wvl,dbnorm2)

# %%
f1,a1 = plt.subplots(5,sharex=True,figsize=(10,15))
for a in a1:
    a.grid(True)
a1[0].plot(lut.wvl,s_0_5_6)
a1[0].set_xlim([350,1700])
a1[-1].set_xlabel('Wavelength [nm]')
a1[1].plot(lut.wvl,snorm)
a1[2].plot(lut.wvl,norm2)
a1[3].plot(lut.wvl,dsp)
a1[4].plot(lut.wvl,dsp2)
a1[0].set_title('original')
a1[1].set_title('normed to max')
a1[2].set_title('normed to 1000 nm')
a1[3].set_title('derivative of normed at 1000 nm using gradient')
a1[4].set_title('another derivative normed at 1000 nm using 3 point lagrangian')

# %% [markdown]
# From above the 3 point lagrangian, adapted from IDL, returns a more 'correct' version of the spectral derivative. There may be some odditites with using the gradient method from numpy.

# %% [markdown]
# Compare to IDL plots:
# spectra:
# <img src="./compare_plots/s_0_5_6.png">
# Normed to max:
# <img src="./compare_plots/norm.png">
# Normed to 1000 nm:
# <img src="./compare_plots/norm2.png">
# Derivative of above:
# <img src="./compare_plots/dsp.png">

# %% [markdown]
# Verify distinct pieces of the derivative plot, and the slope fit to them

# %% [raw]
#  We are now lookign at the linfit routine used in parameters 9, 10, 11, and others

# %%
f2,a2 = plt.subplots(1)
a2.plot(lut.wvl,dsp2,'b+')
a2.plot(lut.wvl,dsp2,'b',label='Normalized derivative')
a2.set_xlim([1000,1077])
a2.set_ylim([-7,2])
a2.grid(True)

# build the linear fit
from linfit import linfit
f,z = linfit(lut.wvl[i1000:i1077],dsp2[i1000:i1077])
print f
print z
print f[1]
a2.plot(lut.wvl[i1000:i1077],f[1]+f[0]*lut.wvl[i1000:i1077],'r',label='linear fit')
a2.set_xlabel('Wavelength [nm]')
a2.set_ylabel('Zenith normalized derivative')
plt.legend()

#linfit output is [m,b], not [b,m] like previously thought
# Out:
# [-0.00775574  5.65476044]
# [[  1.28141527e-04  -1.32964295e-01]
#  [ -1.32964295e-01   1.38030986e+02]]
# 5.65476044013

# %% [markdown]
# Now we look at the derivative at the minimum derivative directly before at 1200 nm. This has to be adjusted for the different wavelength spacing between 4STAR and SSFR.

# %%
f2,a2 = plt.subplots(1)
a2.plot(lut.wvl,dsp2,'bx')
a2.plot(lut.wvl,dsp2,'b')
a2.set_xlim([1150,1250])
a2.set_ylim([-5,4])
a2.plot([1193],[-0.67],'r*')
a2.grid(True)
a2.plot([1198],lut.par[0,5,6,1],'r+')
a2.set_xlabel('Wavelength [nm]')
a2.set_ylabel('Zenith normalized derivative')
