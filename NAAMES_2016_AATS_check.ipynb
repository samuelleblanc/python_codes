# %% [markdown]
# # Introduction
#
# Name:
#
#     NAAMES_2016_AATS_check
#
# Purpose:
#
#     Testing out the archived files from AATS
#
# Input:
#
#     none at command line
#
# Output:
#
#     figures
#
# Keywords:
#
#     none
#
# Dependencies:
#
#     - numpy
#     - scipy : for saving and reading
#     - math
#     - pdb
#     - datetime
#     - load_utils
#     - Run_fuliou
#
# Needed Files:
#
#   - AATS NAAMES AOD ict files
#
#
# Modification History:
#
#     Wrtten: Samuel LeBlanc, NASA Ames, 2018-05-30
#     Modified:

# %% [markdown]
# # Load the defaults modules and setup

# %%
# %config InlineBackend.rc = {}
import matplotlib 
import os
matplotlib.rc_file(os.path.join(os.getcwd(),'file.rc'))
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import numpy as np
import Sp_parameters as Sp
from load_utils import mat2py_time, toutc, load_ict
from Sp_parameters import smooth
from linfit import linfit
from path_utils import getpath
from plotting_utils import make_boxplot

# %%
# %matplotlib notebook

# %%
fp = getpath('NAAMES',path='/mnt/c/Users/sleblanc/Research/NAAMES',make_path=True)
fp
# Out:
# '/mnt/c/Users/sleblanc/Research/NAAMES/'

# %% [markdown]
# # Load the AOD ict files

# %%
vv = 'R0'
d = '20160527'

# %%
fname_aod = fp+'aod_ict/NAAMES_2/NAAMES-AATS-AOD_C130_{}_{vv}.ict'.format(d,vv=vv)
tt,th = load_ict(fname_aod,return_header=True)
# Out:
# ('Start_UTC', 'Latitude', 'Longitude', 'GPS_alt', 'qual_flag', 'AOD0354', 'AOD0380', 'AOD0451', 'AOD0499', 'AOD0520', 'AOD0606', 'AOD0675', 'AOD0779', 'AOD0865', 'AOD0941', 'AOD1019', 'AOD1241', 'AOD1559', 'AOD2139', 'a2', 'a1', 'a0', 'UNCOD0354', 'UNCOD0380', 'UNCOD0451', 'UNCOD0499', 'UNCOD0520', 'UNCOD0606', 'UNCOD0675', 'UNCOD0779', 'UNCOD0865', 'UNCOD0941', 'UNCOD1019', 'UNCOD1241', 'UNCOD1559', 'UNCOD2139')

# %% [markdown]
# # Plot out the data

# %%
plt.figure()
plt.plot(tt['Start_UTC'],tt['AOD0499'])
# Out:
# <img src="data:image/png;base64,...">

# %%
prof = np.array([46296,48896])/3600.0
prof
# Out:
# array([ 12.86      ,  13.58222222])
