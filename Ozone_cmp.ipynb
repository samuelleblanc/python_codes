# %% [markdown]
# # Info
# Name:
#
#     Ozone_cmp
#
# Purpose:
#
#     To compare the ozone from the transit flight of KORUS AQ to OMI ozone amounts.
#
# Input:
#
#     none at command line
#
# Output:
#
#     figures and save files...
#
# Keywords:
#
#     none
#
# Dependencies:
#
#     - load_utils.py : for loading OMI HDF5 files
#     - matplotlib
#     - numpy
#     - scipy : for saving and reading
#     - math
#     - os
#     - gc
#     - pdb
#     - datetime
#
# Needed Files:
#
#   - file.rc : for consistent creation of look of matplotlib figures
#   - ...
#
# Modification History:
#
#     Written: Samuel LeBlanc, OSAN AFB, Korea, 2016-05-03
#     Modified:

# %% [markdown]
# # Import initial modules and default paths

# %%
# %config InlineBackend.rc = {}
import matplotlib 
matplotlib.rc_file('C:\\Users\\sleblan2\\Research\\python_codes\\file.rc')
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import numpy as np
import scipy.io as sio
import Sp_parameters as Sp
import hdf5storage as hs
import load_utils as lm

# %%
from mpl_toolkits.basemap import Basemap,cm

# %%
# %matplotlib notebook

# %%
fp = 'C:/Users/sleblan2/Research/KORUS-AQ/'

# %% [markdown]
# # Load the various data

# %% [markdown]
# ## Load the OMI ozone data for the transit flight

# %%
oz = hs.File(fp+'ozone/','OMI-Aura_L3-OMDOAO3e_2016m0426_v003-2016m0428t023351.he5','r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-d06e13189f8f> in <module>()
# ----> 1 oz = hs.File(fp+'ozone/','OMI-Aura_L3-OMDOAO3e_2016m0426_v003-2016m0428t023351.he5','r')
#
# AttributeError: 'module' object has no attribute 'File'

# %%
import h5py

# %%
import tables

# %%
oz = tables.openFile(fp+'ozone/'+'OMI-Aura_L3-OMDOAO3e_2016m0426_v003-2016m0428t023351.he5',mode='r',root_uep='/HDFEOS/GRIDS')
# Out:
# C:\Python27_64\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   if __name__ == '__main__':

# %%
oz.get_node
# Out:
# <bound method File.get_node of File(filename=C:/Users/sleblan2/Research/KORUS-AQ/ozone/OMI-Aura_L3-OMDOAO3e_2016m0426_v003-2016m0428t023351.he5, title='', mode='r', root_uep='/HDFEOS/GRIDS', filters=Filters(complevel=0, shuffle=False, fletcher32=False, least_significant_digit=None))
# / (RootGroup) ''
# /ColumnAmountO3 (Group) ''
# /ColumnAmountO3/Data Fields (Group) ''
# /ColumnAmountO3/Data Fields/CloudFraction (CArray(720, 1440), zlib(5)) ''
#   atom := Float32Atom(shape=(), dflt=-1.2676506e+30)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (180, 180)
# /ColumnAmountO3/Data Fields/CloudFractionPrecision (CArray(720, 1440), zlib(5)) ''
#   atom := Float32Atom(shape=(), dflt=-1.2676506e+30)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (180, 180)
# /ColumnAmountO3/Data Fields/CloudPressure (CArray(720, 1440), zlib(5)) ''
#   atom := Float32Atom(shape=(), dflt=-1.2676506e+30)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (180, 180)
# /ColumnAmountO3/Data Fields/CloudPressurePrecision (CArray(720, 1440), zlib(5)) ''
#   atom := Float32Atom(shape=(), dflt=-1.2676506e+30)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (180, 180)
# /ColumnAmountO3/Data Fields/ColumnAmountO3 (CArray(720, 1440), zlib(5)) ''
#   atom := Float32Atom(shape=(), dflt=-1.2676506e+30)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (180, 180)
# /ColumnAmountO3/Data Fields/ColumnAmountO3Precision (CArray(720, 1440), zlib(5)) ''
#   atom := Float32Atom(shape=(), dflt=-1.2676506e+30)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (180, 180)
# /ColumnAmountO3/Data Fields/EffectiveTemperature (CArray(720, 1440), zlib(5)) ''
#   atom := Int8Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (180, 180)
# /ColumnAmountO3/Data Fields/EffectiveTemperaturePrecision (CArray(720, 1440), zlib(5)) ''
#   atom := Int8Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (180, 180)
# /ColumnAmountO3/Data Fields/GhostColumnAmountO3 (CArray(720, 1440), zlib(5)) ''
#   atom := Float32Atom(shape=(), dflt=-1.2676506e+30)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (180, 180)
# /ColumnAmountO3/Data Fields/SolarZenithAngle (CArray(720, 1440), zlib(5)) ''
#   atom := Float32Atom(shape=(), dflt=-1.2676506e+30)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (180, 180)
# /ColumnAmountO3/Data Fields/TerrainHeight (CArray(720, 1440), zlib(5)) ''
#   atom := Int16Atom(shape=(), dflt=-32767)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (180, 180)
# /ColumnAmountO3/Data Fields/TerrainReflectivity (CArray(720, 1440), zlib(5)) ''
#   atom := Float32Atom(shape=(), dflt=-1.2676506e+30)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (180, 180)
# /ColumnAmountO3/Data Fields/ViewingZenithAngle (CArray(720, 1440), zlib(5)) ''
#   atom := Float32Atom(shape=(), dflt=-1.2676506e+30)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (180, 180)
# >

# %%
ooo = oz.getNode('/ColumnAmountO3/Data Fields/ColumnAmountO3')
# Out:
# C:\Python27_64\WinPython-64bit-2.7.6.4\python-2.7.6.amd64\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: getNode() is pending deprecation, use get_node() instead. You may use the pt2to3 tool to update your source code.
#   if __name__ == '__main__':

# %%
plt.figure()
plt.contourf(ooo.read(),clevels=[200,225,250,275,300,325,350,375,400,425,450])
# Out:
# <img src="data:image/png;base64,...">
# <matplotlib.contour.QuadContourSet instance at 0x00000000203DBBC8>

# %%
oz.ColumnAmountO3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-eeb5536081d9> in <module>()
# ----> 1 oz.ColumnAmountO3
#
# AttributeError: 'File' object has no attribute 'ColumnAmountO3'

# %%
oz.keys()
# Out:
# [u'HDFEOS', u'HDFEOS INFORMATION']

# %%
oz = h5py.File(fp+'ozone/'+'OMI-Aura_L3-OMDOAO3e_2016m0426_v003-2016m0428t023351.he5','r')

# %%
oz['HDFEOS']
