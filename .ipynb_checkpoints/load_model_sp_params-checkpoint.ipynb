# %%
# %matplotlib inline
from matplotlib import rc_file
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import numpy as np, h5py
import plotly.plotly as py
import scipy.io as sio
import math
import os
py.sign_in("samuelleblanc", "4y3khh7ld4")
print 'C:\\Users\\sleblan2\\Research\\python_codes\\file.rc'
rc_file('C:\\Users\\sleblan2\\Research\\python_codes\\file.rc')

#import mpld3
#mpld3.enable_notbeook()
# Out:
# C:\Users\sleblan2\Research\python_codes\file.rc

# %%
# set the basic directory path
fp='C:\\Users\\sleblan2\\Research\\TCAP\\'

# %%
# load the idl save file containing the modeled radiances
s=sio.idl.readsav(fp+'model/sp_v1_20130219_4STAR.out')
print s.keys()
print 'sp', s.sp.shape
print 'sp (wp, wvl, z, re, ta)'
# Out:
# ['tau', 'ab', 'pw', 'sp_irrdn', 'sp', 'zenlambda', 'sza', 'zout', 'sp_irrup', 'z', 'ref']
# sp (2, 1556, 2, 35, 24)
# sp (wp, wvl, z, re, ta)

# %%
# create custom key for sorting via wavelength
iwvls = np.argsort(s.zenlambda)
s.zenlambda.sort()

# %%
# load the matlab file containing the measured TCAP radiances
m = sio.loadmat(fp+'4STAR/20130219starzen_rad.mat')
sm = sio.idl.AttrDict(m)
print sm.keys()
print 'Measured radiance Shape: ', sm.rad.shape

print np.nanmax(sm.rad[sm.good[100],:])
sm.good[100]
# Out:
# ['utc', 'rad', 'good', 'nm', '__version__', '__header__', '__globals__']
# Measured radiance Shape:  (3296, 1512)
# 0.110006678277
# array([634], dtype=uint16)

# %% [markdown]
# #### Next section loads a few functions that can be used for typical analysis

# %%
def nanmasked(x):
    " Build an array with nans masked out and the mask output"
    mask = ~np.isnan(x)
    maskA = x[mask]
    return (maskA,mask)

def closestindex(a,x):
    " Get the index from a of the closest value from x "
    return min(range(len(a)), key=lambda i: abs(a[i]-x))

def norm2max(x):
    " Returns a spectrum, x, that is normalized by its maximum value, ignores nans "
    return x/np.nanmax(x)
    
time_ref=17.22
ii = closestindex(sm.utc,time_ref)
rad,mask = nanmasked(sm.rad[sm.good[ii],:])

# %% [markdown]
# #### Plotting commences

# %%
# set up plotting of a few of the zenith radiance spectra
def pltzen(tit='Zenith spectra'):
    "Plotting of zenith measurements in radiance units"
    fig,ax = plt.subplots()
    ax.plot(sm.nm[mask],rad,lw=2, c='k', label='4STAR measured at: '+str(time_ref))
    plt.title(tit)
    plt.ylabel('Radiance [Wm$^{-2}$nm$^{-1}$sr$^{-1}$]')
    plt.xlabel('Wavelength [nm]')
    plt.xlim([350,1700])
    plt.ylim([0,0.22])
    plt.legend(frameon=False)
    #plot_url = py.plot_mpl(fig)
    return fig,ax

def norm():
    "Plotting of zenith measurements in normalized radiance"
    fig,ax = plt.subplots()
    ax.plot(sm.nm[mask],norm2max(rad),lw=2, c='k', label='4STAR measured at: '+str(time_ref))
    plt.title('Zenith spectra')
    plt.ylabel('Normalized Radiance')
    plt.xlabel('Wavelength [nm]')
    plt.xlim([350,1700])
    plt.ylim([0,1.0])
    plt.legend(frameon=False)
    #plot_url = py.plot_mpl(fig)
    return fig,ax

def dashlen(dashlength,dashseperation,fig=plt.gcf()):
    """ Build a list of dash length that fits within the current figure or figure denoted by fig, 
        each dash is length dashlength, with its centers at dashseperation """
    totallen = fig.get_figwidth()
    numdash = int(totallen/dashseperation)*2
    f=lambda i: dashlength if i%2==0 else dashseperation-dashlength
    return tuple([f(i) for i in range(numdash)])

def plot_line_gradients(ax,s,names,cmap,iphase,irefs,itau,iwvls,pos,normalize=False):
    """ Make multiple lines on the subplot ax of the spectra s, for the case defined by names with the cmap
      for one particular phase (iphase), range of refs (irefs) and at one itau. Returns the axis handles for the thin and thick ref """
    rf = range(irefs[0],irefs[1])
    colors = plt.cm._generate_cmap(cmap,int(len(rf)*2.0))
    for ir in rf:
        if not(normalize):
            a1 = ax.plot(s.zenlambda,s.sp[iphase,iwvls,0,ir,itau],
                         color=(0.2,0.2,0.2),
                         lw=1.8*ir/irefs[1])
            ax.plot(s.zenlambda,s.sp[iphase,iwvls,0,ir,itau],
                     color=colors(ir),
                     lw=1.7*ir/irefs[1])
            ax.text(pos[0],pos[1],names,color=colors(irefs[1]))
        else:
            a1 = ax.plot(s.zenlambda,norm2max(s.sp[iphase,iwvls,0,ir,itau]),
                         color=(0.2,0.2,0.2),
                         lw=1.8*ir/irefs[1])
            ax.plot(s.zenlambda,norm2max(s.sp[iphase,iwvls,0,ir,itau]),
                     color=colors(ir),
                     lw=1.7*ir/irefs[1])    
            ax.text(pos[0],pos[1]/0.22,names,color=colors(irefs[1]))
        if ir == rf[0]:
            alow = a1
        if ir == rf[-1]:
            ahigh = a1
    
    return [alow,ahigh]

# %%
fig,ax=pltzen()

# %%
# now go through and add the different modeled spectra
fig,ax=pltzen()

lines = [('Liquid Cloud Model, COD=0.5','Reds',0,[0,13],1,[420,0.01]),
         ('Ice Cloud Model, COD=0.5','Greens',1,[13,34],1,[380,0.02]),
         ('Liquid Cloud Model, COD=10','Purples',0,[0,13],9,[700,0.16]),
         ('Ice Cloud Model, COD=10','Blues',1,[13,34],9,[750,0.15])]

for names,cmap,iphase,irefs,itau,pos in lines:
    [alow,ahigh] = plot_line_gradients(ax,s,names,cmap,iphase,irefs,itau,iwvls,pos)
    
lbl=["Small R$_{eff}$ (Ice=" + str(s.ref[34]) + " $\mu m$, Liquid=" + str(s.ref[13]) + " $\mu m$)",
     "Large R$_{eff}$ (Ice=" + str(s.ref[13]) + " $\mu m$, Liquid=" + str(s.ref[0]) + " $\mu m$)"]
plt.legend([alow[0],ahigh[0]],
           lbl,
           frameon=False,
           loc=7)
ax.text(600,0.19,'4STAR Measurement')

# %%
fig,ax=norm()
for names,cmap,iphase,irefs,itau,pos in lines:
    [alow,ahigh] = plot_line_gradients(ax,s,names,cmap,iphase,irefs,itau,iwvls,pos,normalize=True)
plt.legend([alow[0],ahigh[0]],
           lbl,
           frameon=False,
           loc=7)
ax.text(600,0.19/0.22,'4STAR Measurement')

# %% [markdown]
# Create a new class for spectra that returns easy plotting, normalization, parameters, etc.

# %%
class Sp:
    """ 
    Sp: spectrum class object that has all the tools for easy spectra analysis
    """
    def __init__(self,s,**kwargs):
        if 'nm' in s:
            self.wvl = s['nm']
        if 'zenlambda' in s:
            self.wvl = s['zenlambda']
        if 'wvl' in s:
            self.wvl = s['wvl']
        self.iwvls = np.argsort(self.wvl)
        self.wvl = np.sort(self.wvl)
        self.nwvl = len(self.wvl)
        self.sp = wvlsort(self,s)
        self.norm = normsp(self.sp)
        self.par = params(self.sp,self.wvl)
        
    def wvlsort(self,s):
        "Function to sort spectra along the wavelength axis"
        iwvls = self.iwvls
        if 'sp' in s:
            ui = [i for i in range(s['sp'].ndim) if s['sp'].shape[i] == len(iwvls)]
            if 1 in ui:
                sp = s['sp'][:,iwvls,:,:,:]
            else: raise LookupError
        if 'rad' in s:
            ui = [i for i in range(s['rad'].ndim) if s['rad'].shape[i] == len(iwvls)]
            if 1 in ui:
                sp = s['rad'][:,iwvls]
            else: 
                sp = s['rad'][iwvls,:]
        return sp
    
    def normsp(sp):
        " Function to return the normalized spectra list"
        idxwvl = [i for i in range(sp.ndim) if sp.shape[i] == len(self.iwvls)]
        norm = sp/np.nanmax(sp,axis=idxwl[0])
        return norm
        
    def nanmasked(x):
        " Build an array with nans masked out and the mask output"
        mask = ~np.isnan(x)
        maskA = x[mask]
        return (maskA,mask)
    
    def norm2max(x):
        " Returns a spectrum, x, that is normalized by its maximum value, ignores nans "
        return x/np.nanmax(x)
        
    def params(sp,wvl):
        " Runs through each spectrum in the sp array to calculate the parameters"
        npar = 16
        dims = [sp.shape[i] for i in range(len(sp.shape))]
        ui = [i for i in range(sp.ndim) if sp.shape[i] == len(wvl)]
        dims[ui[0]] = npar
        par = np.empty((dims))
        par[:] = np.NAN
        
    def closestindex(a,x):
        " Get the index from a of the closest value from x "
        return min(range(len(a)), key=lambda i: abs(a[i]-x))
        
    def param(sp,wvl):
        " Calculates the parameters from a spectrum."
        norm = normsp(sp)
        i1000 = closestindex(wvl,1000)
        norm2 = sp/sp[i1000]
        dsp = np.gradient(norm2,wvl/1000)
        npar = 16
        imaxwvl = wvl.index(np.nanmax(sp))
        maxwvl = wvl[imaxwvl]
        # now calculate each parameter
        i1077 = closestindex(wvl,1077)
        fit0 = polyfit(wvl[i1000:i1077],norm2[i1000:i1077])
        fit0_fn = poly1d(fit0)
        i1493 = closestindex(wvl,1493)
        i1600 = closestindex(wvl,1600)
        fit7 = polyfit(wvl[i1493:i1600],norm2[i1493:i1600])
        fit7_fn = poly1d(fit7)
        fit8 = polyfit(wvl[i1000:i1077],dsp[i1000:i1077])
        i1200 = closestindex(wvl,1200)
        i1300 = closestindex(wvl,1300)
        fit9 = polyfit(wvl[i1200:i1300],dsp[i1200:i1300])
        i530 = closestindex(wvl,530)
        i610 = closestindex(wvl,610)
        fit10 = polyfit(wvl[i530:i610]/1000,norm[i530:i610])
        i1565 = closestindex(wvl,1565)
        i1634 = closestindex(wvl,1634)
        fit14 = polyfit(wvl[i1565:i1634],sp[i1565:1634]/norm[i1565])
        par = [sum(norm2[i1000:i1077]-fit0_fn(wvl[i1000:i1077])),
               dsp[closestindex(wvl,1193)],
               dsp[closestindex(wvl,1493)],
               norm[closestindex(wvl,1198)]/norm[closestindex(wvl,1236)],
               np.nanmean(norm[closestindex(wvl,1248):closestindex(wvl,1270)]),
               np.nanmean(norm[closestindex(wvl,1565):closestindex(wvl,1644)]),
               np.nanmean(norm[closestindex(wvl,1000):closestindex(wvl,1050)]),
               sum(norm2[i1493:i1600]-fit7_fn(wvl[i1493:i1600])),
               fit8[1],
               fit9[1],
               fit10[1],
               norm[closestindex(wvl,1040)],
               norm[closestindex(wvl,1000)]/norm[closestindex(wvl,1065)],
               norm[closestindex(wvl,600)]/norm[closestindex(wvl,870)],
               np.nanmax(0.003,fit14[1]),
               sp[closestindex(wvl,515)]
               ]
        return par

# %%
plt.plot(sm.nm[mask],np.gradient(rad,sm.nm[mask]*1000))

# %%
# Out:
# [1, 2, 3, 4, 6, 5]
# [1 2 3 4 5 6]

# %%
# Out:
# 1556
# [1]

# %%
ss = s.sp[:,iwvls,:,:,:]
print ss.shape
print s.sp[0,1200,0,0,0], ss[0,1200,0,0,0]
# Out:
# (2, 1556, 2, 35, 24)
# 0.00589039 0.00589039

# %%
dims = [s.sp.shape[i] for i in range(len(s.sp.shape))]
ui[0]
dims[ui[0]] = 15
print dims
# Out:
# [2, 15, 2, 35, 24]

# %%
# Out:
# 5
# [':', 'iwvls', ':', ':', ':']
# <type 'list'>

# %%
# Out:
# [0, 1]
